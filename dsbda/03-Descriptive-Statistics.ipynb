# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## DATA PREPROCESSING

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df["College"] = df["College"].fillna(df["College"].mode())
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# ## Summury Stats

# %%
height_groups = df.groupby(df["Height"])
height_groups.head()
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 0       Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 1         Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 2        John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 3         R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 6       Jordan Mickey          Boston Celtics    55.0       PF  21.0    6-8
# ..                ...                     ...     ...      ...   ...    ...
# 203         Ty Lawson          Indiana Pacers    10.0       PG  28.0   5-11
# 230    Raymond Felton        Dallas Mavericks     2.0       PG  31.0    6-1
# 244  Patrick Beverley         Houston Rockets     2.0       PG  27.0    6-1
# 329     Spencer Hawes       Charlotte Hornets     0.0       PF  28.0    7-1
# 435    Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0    7-1
#
#      Weight            College        Salary
# ...

# %%
height_groups["Salary"].describe()
# Out:
#         count          mean           std         min          25%  \
# Height
# 5-11      3.0  5.891553e+05  7.926627e+05     55722.0    133733.00
# 5-9       1.0  6.912869e+06           NaN   6912869.0   6912869.00
# 6-0      10.0  5.784075e+06  6.337144e+06    947276.0   2437500.00
# 6-1      12.0  5.456567e+06  4.585905e+06    700902.0   1898610.00
# 6-10     34.0  5.111545e+06  5.162012e+06    222888.0   1044792.25
# 6-11     29.0  5.920326e+06  7.067208e+06    245177.0   1140240.00
# 6-2      15.0  2.862862e+06  2.576949e+06    525093.0    947276.00
# 6-3      27.0  5.765194e+06  5.759044e+06    189455.0   1841940.00
# 6-4      28.0  4.358526e+06  5.135309e+06    134215.0   1006902.75
# 6-5      30.0  4.379143e+06  4.235717e+06     55722.0   1159800.00
# 6-6      37.0  2.963790e+06  3.167094e+06    167406.0    947276.00
# 6-7      37.0  3.716167e+06  4.684027e+06    200600.0    981348.00
# 6-8      36.0  5.616665e+06  5.807020e+06     83397.0   1128220.00
# ...

# %%
df["Age"].min()
# Out:
# 19.0

# %%
df["Age"].max()
# Out:
# 40.0

# %%
bins = [19,25,31,36,40]
labels = ["19-24", "25-30", "31-35", "36-40"]
df["ageGroup"] = pd.cut(df["Age"], bins=bins, labels=labels)

# %%
df["ageGroup"]
# Out:
# 0      19-24
# 1      19-24
# 2      25-30
# 3      19-24
# 6      19-24
#        ...
# 449    19-24
# 451    25-30
# 452    19-24
# 453    25-30
# 456    25-30
# Name: ageGroup, Length: 373, dtype: category
# Categories (4, object): ['19-24' < '25-30' < '31-35' < '36-40']

# %%
df.ageGroup.value_counts()
# Out:
# ageGroup
# 19-24    171
# 25-30    151
# 31-35     41
# 36-40      8
# Name: count, dtype: int64

# %%
age_groups = df.groupby("ageGroup")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17704\2584305224.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_groups = df.groupby("ageGroup")

# %%
age_groups["Salary"].describe()
# Out:
#           count          mean           std       min        25%        50%  \
# ageGroup
# 19-24     171.0  3.099927e+06  3.689180e+06   55722.0   947276.0  1572360.0
# 25-30     151.0  6.433366e+06  5.801305e+06   55722.0  1298000.0  4775000.0
# 31-35      41.0  4.780806e+06  5.458128e+06  200600.0  1449187.0  3300000.0
# 36-40       8.0  2.997202e+06  2.180022e+06  222888.0   773144.5  3732009.5
#
#                    75%         max
# ageGroup
# 19-24     3.495566e+06  16407501.0
# 25-30     1.002500e+07  21468695.0
# 31-35     5.158539e+06  22875000.0
# 36-40     4.882013e+06   5250000.0

# %% [markdown]
# ## 3.2

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris = iris.rename(columns = {
    "SepalLengthCm" : "sepal_length",
    "SepalWidthCm" : "sepal_width",
    "PetalLengthCm" : "petal_length",
    "PetalWidthCm" : "petal_width"
})

# %%
iris.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
species_grp = iris.groupby(iris["Species"])

# %%
species_grp["sepal_length"].describe()
# Out:
#                  count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
species_grp["sepal_width"].describe()
# Out:
#                  count   mean       std  min    25%  50%    75%  max
# Species
# Iris-setosa       50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
species_grp["petal_length"].describe()
# Out:
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
species_grp["petal_width"].describe()
# Out:
#                  count   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa       50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor   50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica    50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5
